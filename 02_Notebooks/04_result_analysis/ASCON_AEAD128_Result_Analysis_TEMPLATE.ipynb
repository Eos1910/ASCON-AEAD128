# %% [markdown]
# # ASCON Result Analysis Template

# %%
from pathlib import Path
import pandas as pd
import numpy as np

PROJECT_DIR = Path(r"C:\Users\thetp\Downloads\ASCON_FYP")
RESULTS_ROOT = PROJECT_DIR / r"04_Results\cnn256_topk_training"

summary_files = list(RESULTS_ROOT.rglob("summary_results*.csv"))
print("Summary files found:")
for p in summary_files:
    print(p)

# Load the summary you want manually, for example:
# df = pd.read_csv(summary_files[-1])
