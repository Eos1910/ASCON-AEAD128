# %% [markdown]
# # ASCON-AEAD-128 Training Template
#
# Use this after dataset verification. It points to the ASCON_FYP dataset root and can be adapted from the ACORNv3 V3 CNN training notebook.

# %%
from pathlib import Path

PROJECT_DIR = Path(r"C:\Users\thetp\Downloads\ASCON_FYP")
DATASET_ROOT = PROJECT_DIR / r"03_Data\tight_trigger_keybyte_auto30k"
RESULTS_ROOT = PROJECT_DIR / r"04_Results\cnn256_topk_training"
MODELS_ROOT = PROJECT_DIR / r"05_Models\cnn_baseline_models"

print("PROJECT_DIR:", PROJECT_DIR)
print("DATASET_ROOT:", DATASET_ROOT)
print("RESULTS_ROOT:", RESULTS_ROOT)
print("MODELS_ROOT:", MODELS_ROOT)

# Recommended next step:
# Copy the working ACORNv3_CNN256_TopK_Model_Training_V3_ALL16_TOP2 notebook,
# change PROJECT_DIR/DATASET_ROOT to ASCON_FYP,
# then train byte 00 first before training all 16 bytes.
